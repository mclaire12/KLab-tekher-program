# %%
print("Hello World!")
# Out:
# Hello World!

# %%
name = input("What is your name? ")
age = int(input("How old are you? "))

print(f"Hello {name}!")
print(f"You are {age} years old.")
# Out:
# What is your name?  Marie claire
# How old are you?  24
# Hello Marie claire!
# You are 24 years old.

# %%
print("I'm claire")
# Out:
# I'm claire
