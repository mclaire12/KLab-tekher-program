# %%
model_name = "iris-clissifier"
accuracy = 0.87
is_trained = True
print(f"{model_name} reached {accuracy: .4%} and it is trainde well")
# Out:
# iris-clissifier reached  87.0000% and it is trainde well

# %% [raw]
# print("conversion")
#
# raw_value = "0.87"
# score = float(raw_value)
# rounded = int(score * 100)
#
# def to_float(value, default=0.0):
# try:
# return float(value)
# except (TypeError, ValueError):
# return default
#
# print(to_float("1.43"), to_float("N/A"))

# %%
accuracy,threshold,latency_ms = 0.91, 0.90, 240

if accuracy >= threshold and latency_ms < 300:
    decision = "ship it"
elif accuracy >= threshold:
    decision = "accurate but too slow"
else:
    decision = "keep training" 
status = "pass" if accuracy >= threshold else "fail"
print(f"{decision}")
# Out:
# ship it

# %%
feature = ["age", "income","region"] #list - ordered mutable
image_shape = (244, 244, 4) # tuple  
config = {"model":"lohreg", "accuracy":1.0, "threshold":0.9}# dictionary
labels = {"cat","dog", 1, "mouse"} # set-unique value

# %%
print(len(feature))
# Out:
# 3

# %%
print(config["threshold"])
# Out:
# 0.9

# %%
print(labels)
# Out:
# {1, 'mouse', 'dog', 'cat'}

# %%
import numpy as np 
import pandas as pd

scores = np.array([0.71, 0.83, 0.93])
print(scores * 100)
# Out:
# [71. 83. 93.]

# %%
print(
